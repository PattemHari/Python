# %%
print("Hello")
# Out:
# Hello

# %%
#Creating a diractry
import os
new_directry = 'package1'
os.makedirs(new_directry)
print(f'the direactry {new_directry} is created successfully and  now you can chick')
# Out:
# the direactry package1 is created successfully and  now you can chick

# %%
print(os.listdir('.'))
# Out:
# ['package1']
